# %%
from modeling_pipeline_utils import load_feature_csv, run_experiments

train_csv = r"C:\Users\Alina\Downloads\drive-download-20260109T105242Z-1-001\train_merged_LE_RE.csv"
test_csv  = r"C:\Users\Alina\Downloads\drive-download-20260109T105242Z-1-001\test_merged_LE_RE.csv"

X_train, y_train, X_test, y_test = load_feature_csv(train_csv, test_csv)

results, metrics_table, jaccard = run_experiments(
    X_train, y_train, X_test, y_test,
    top_n=10,
    nsamples_ci=2000
)
# Out:
# C:\Users\Alina\anaconda3\Lib\site-packages\sklearn\feature_selection\_variance_threshold.py:114: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   self.variances_ = np.nanvar(X, axis=0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       4 test_csv  = r"C:\Users\Alina\Downloads\drive-download-20260109T105242Z-1-001\test_merged_LE_RE.csv"
#       6 X_train, y_train, X_test, y_test = load_feature_csv(train_csv, test_csv)
# ----> 8 results, metrics_table, jaccard = run_experiments(
#       9     X_train, y_train, X_test, y_test,
#      10     top_n=10,
#      11     nsamples_ci=2000
#      12 )
#
# File ~\OneDrive\Documents\GitHub\Radiomics_for_CEM\modeling_pipeline_utils.py:344, in run_experiments(X_train, y_train, X_test, y_test, top_n, nsamples_ci)
#     341     X_test_sel = X_test_p.loc[:, mask]
#     343     label = f"{model_name} | {selector_name}"
# --> 344     thr, cm, cm_norm, df_metrics = fit_and_evaluate(
#     345         model,
#     346         X_train_sel,
#     347         y_train,
#     348         X_test_sel,
#     349         y_test,
#     350         label=label,
#     351         nsamples_ci=nsamples_ci,
#     352     )
#     354     results.append(ExperimentResult(
#     355         model_name=model_name,
#     356         selector_name=selector_name,
#    (...)    363         extra=extra,
#     364     ))
#     366 # 3) Comparison tables
#
# File ~\OneDrive\Documents\GitHub\Radiomics_for_CEM\modeling_pipeline_utils.py:205, in fit_and_evaluate(model, X_train_sel, y_train, X_test_sel, y_test, label, nsamples_ci)
#     202 thr = float(get_optimal_threshold(y_train, proba_train))
#     204 # Metrics with CI strings (already includes thresholded metrics internally)
# --> 205 _, df_metrics = get_stats_with_ci(y_test, proba_test, label, thr, nsamples=nsamples_ci)
#     207 # Confusion matrices on test
#     208 y_test_pred = (np.asarray(proba_test) > thr).astype(int)
#
# File ~\OneDrive\Documents\GitHub\Radiomics_for_CEM\radiomics_pipeline\utils.py:174, in get_stats_with_ci(y_label, y_pred, label, optimal_threshold, nsamples)
#     170 dict_distributions["auc"], dict_results["auc"], _, _ = get_ci_for_auc(y_label, y_pred, nsamples = nsamples)
#     172 y_pred_binary = (np.array(y_pred) > optimal_threshold).astype(int)
# --> 174 dict_distributions["accuracy"], dict_results["accuracy"] = get_ci(y_label, y_pred_binary, sklearn.metrics.accuracy_score, nsamples = nsamples)
#     175 dict_distributions["precision"], dict_results["precision"] = get_ci(y_label, y_pred_binary, sklearn.metrics.precision_score, nsamples = nsamples)
#     176 dict_distributions["specificity"], dict_results["specificity"] = get_ci(np.ones(len(y_label)) - y_label, np.ones(len(y_pred_binary)) - y_pred_binary, sklearn.metrics.recall_score, nsamples = nsamples)
#
# File ~\OneDrive\Documents\GitHub\Radiomics_for_CEM\radiomics_pipeline\utils.py:134, in get_ci(label, pred, f, nsamples)
#     133 def get_ci(label, pred, f, nsamples= 2000):
# --> 134     stats, ci = bootstrap(label, pred, f, samples= samples)
#     135     n, d = nom_den(label, pred, f)
#     136     return stats, ["%5d/%5d (%5d %% )  CI [%0.2f,%0.2f]" % (n, d, int(f(label, pred) * 100), ci[0], ci[1])]
#
# NameError: name 'samples' is not defined

# %%
from modeling_pipeline_utils import load_feature_csv, run_experiments

# Update these paths to point to where your CSV files are actually located
# For example, if they're in your current working directory:
train_csv = r"C:\Users\Alina\Downloads\drive-download-20260109T105242Z-1-001\train_merged_LE_RE.csv"
test_csv = r"C:\Users\Alina\Downloads\drive-download-20260109T105242Z-1-001\test_merged_LE_RE.csv"

# Or provide the full correct path to your files:
# train_csv = r"C:\correct\path\to\train_merged_LE_RE.csv"
# test_csv = r"C:\correct\path\to\test_merged_LE_RE.csv"

X_train, y_train, X_test, y_test = load_feature_csv(train_csv, test_csv)

results, metrics_table, jaccard = run_experiments(
    X_train, y_train, X_test, y_test,
    top_n=10,
    nsamples_ci=2000
)
# Out:
# C:\Users\Alina\anaconda3\Lib\site-packages\sklearn\feature_selection\_variance_threshold.py:114: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   self.variances_ = np.nanvar(X, axis=0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#       8 # Or provide the full correct path to your files:
#       9 # train_csv = r"C:\correct\path\to\train_merged_LE_RE.csv"
#      10 # test_csv = r"C:\correct\path\to\test_merged_LE_RE.csv"
#      12 X_train, y_train, X_test, y_test = load_feature_csv(train_csv, test_csv)
# ---> 14 results, metrics_table, jaccard = run_experiments(
#      15     X_train, y_train, X_test, y_test,
#      16     top_n=10,
#      17     nsamples_ci=2000
#      18 )
#
# File ~\OneDrive\Documents\GitHub\Radiomics_for_CEM\modeling_pipeline_utils.py:291, in run_experiments(X_train, y_train, X_test, y_test, top_n, nsamples_ci)
#     288 """Run all configured experiments and return results plus comparison tables."""
#     290 # 1) Preprocess (fit on train, apply to test)
# --> 291 mean_std, var_selector, to_drop, X_train_p = preprocessing_train(X_train)
#     292 X_test_p = preprocessing_test(X_test, mean_std, var_selector, to_drop)
#     294 # 2) Define model + selector grid
#
# File ~\OneDrive\Documents\GitHub\Radiomics_for_CEM\radiomics_pipeline\utils.py:43, in preprocessing_train(df_train_features, variance_threshold, corr_threshold)
#      40 selector.fit(df)
#      41 thres_dataset_train = df.loc[:, selector.get_support()]
# ---> 43 to_drop = get_correlated_features_to_drop(thres_dataset_train, corr_threshold=corr_threshold)
#      44 decor_dataset_train = thres_dataset_train.drop(to_drop, axis=1, errors="ignore")
#      45 return mean_std, selector, to_drop, decor_dataset_train
#
# File ~\OneDrive\Documents\GitHub\Radiomics_for_CEM\radiomics_pipeline\utils.py:19, in get_correlated_features_to_drop(thres_dataset_train, corr_threshold)
#      17 val = upper_tri.at[row, column]
#      18 if pd.notna(val) and val > corr_threshold:
# ---> 19     if np.nansum(upper_tri[column].values) > np.nansum(upper_tri[row].values):
#      20         to_drop.append(column)
#      21     else:
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:726, in nansum(a, axis, dtype, out, keepdims, initial, where)
#     634 @array_function_dispatch(_nansum_dispatcher)
#     635 def nansum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#     636            initial=np._NoValue, where=np._NoValue):
#     637     """
#     638     Return the sum of array elements over a given axis treating Not a
#     639     Numbers (NaNs) as zero.
#    (...)    724
#     725     """
# --> 726     a, mask = _replace_nan(a, 0)
#     727     return np.sum(a, axis=axis, dtype=dtype, out=out, keepdims=keepdims,
#     728                   initial=initial, where=where)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:104, in _replace_nan(a, val)
#     102     mask = np.not_equal(a, a, dtype=bool)
#     103 elif issubclass(a.dtype.type, np.inexact):
# --> 104     mask = np.isnan(a)
#     105 else:
#     106     mask = None
#
# KeyboardInterrupt:
